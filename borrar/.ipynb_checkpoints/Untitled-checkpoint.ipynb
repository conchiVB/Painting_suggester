# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
 
# %matplotlib inline

path_bs='./data/'

# Read in the image
image = cv2.imread(path_bs + "AH01.jpg")
 
# Change color to RGB (from BGR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
 
plt.imshow(image)

# %%
image.shape
# Out:
# (1094, 750, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
 
# %matplotlib inline

path_bs='./data/brush_strokes/'

# Read in the image
image = cv2.imread(path_bs + "bs_04.jpg")
 
# Change color to RGB (from BGR)
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
 
plt.imshow(image)

# %%
# Reshaping the image into a 2D array of pixels and 3 color values (RGB)
pixel_vals = image.reshape((-1,3))
 
# Convert to float type
pixel_vals = np.float32(pixel_vals)

# %%
#the below line of code defines the criteria for the algorithm to stop running,
#which will happen is 100 iterations are run or the epsilon (which is the required accuracy)
#becomes 85%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)
 
# then perform k-means clustering wit h number of clusters defined as 3
#also random centres are initially choosed for k-means clustering
k = 20
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
 
# convert data into 8-bit values
centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]
 
# reshape data into the original image dimensions
segmented_image = segmented_data.reshape((image.shape))
 
plt.imshow(segmented_image)

# %%
type(retval)
# Out:
# float

# %%
retval
# Out:
# 3627816.3773467443

# %%
type(labels)

unique, counts = np.unique(labels, return_counts=True)

result = np.column_stack((unique, counts)) 
print (result)
# Out:
# [[    0  1986]
#  [    1  1606]
#  [    2  1488]
#  [    3  1461]
#  [    4     1]
#  [    5  2179]
#  [    6  1506]
#  [    7  1454]
#  [    8 18327]
#  [    9  1882]
#  [   10  7166]
#  [   11  2447]
#  [   12  6523]
#  [   13  2828]
#  [   14 11603]
#  [   15 27135]
#  [   16   132]
#  [   17   176]
#  [   18 83155]
#  [   19     1]]

# %%
labels[].count_di
# Out:
#   File "/tmp/ipykernel_2776/3298055227.py", line 1
#     labels[].count_di
#            ^
# SyntaxError: invalid syntax

# %%
type(segmented_data)
# Out:
# numpy.ndarray

# %%
segmented_data.shape
# Out:
# (173056, 3)

# %%
segmented_data[0]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
import os, sys
from PIL import Image

path_bs='./data/brush_strokes/'
im = Image.open(path_bs + "bs_05.jpg")

newsize = (300,300)
im1 = im.resize(newsize)

#im1_new = add_margin(im1, 20, 20, 20, 20, (255, 255, 255))

display(im1) 
out = im1.convert("RGB")
out_rgb = out.convert("L")

display(out_rgb)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F745C68E100>
# <PIL.Image.Image image mode=L size=300x300 at 0x7F745C657EB0>

# %%
# de momento, el mejor códugo para hacer lo que quiero*  LIMPIO


import cv2

path_bs='./data/brush_strokes/'
image = cv2.imread(path_bs + "bs_06.jpg")
canny = cv2.Canny(image, 10, 150)
canny = cv2.dilate(canny, None, iterations=1)
canny = cv2.erode(canny, None, iterations=1)

contours,hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE) # OpenCV 4

cv2.drawContours(image, contours, -1, (0,255,0), 3) #cv2.drawContours(image, contours, -1, (0,255,0), 2)  
cv2.imshow('image',image)
cv2.waitKey(0)
# Out:
# QObject::moveToThread: Current thread (0x55ebb6d0d6b0) is not the object's thread (0x55ebb73172f0).
# Cannot move to target thread (0x55ebb6d0d6b0)
#
# QObject::moveToThread: Current thread (0x55ebb6d0d6b0) is not the object's thread (0x55ebb73172f0).
# Cannot move to target thread (0x55ebb6d0d6b0)
#
# QObject::moveToThread: Current thread (0x55ebb6d0d6b0) is not the object's thread (0x55ebb73172f0).
# Cannot move to target thread (0x55ebb6d0d6b0)
#
# QObject::moveToThread: Current thread (0x55ebb6d0d6b0) is not the object's thread (0x55ebb73172f0).
# Cannot move to target thread (0x55ebb6d0d6b0)
#
# QObject::moveToThread: Current thread (0x55ebb6d0d6b0) is not the object's thread (0x55ebb73172f0).
# Cannot move to target thread (0x55ebb6d0d6b0)
#
# QObject::moveToThread: Current thread (0x55ebb6d0d6b0) is not the object's thread (0x55ebb73172f0).
# Cannot move to target thread (0x55ebb6d0d6b0)
#
# ...

# %%
import numpy as np
import cv2

path_bs='./data/brush_strokes/'
image = cv2.imread(path_bs + "bs_06.jpg")
#hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)


lower = np.array([0, 71, 0], dtype="uint8")
upper = np.array([180, 255, 255], dtype="uint8")
mask = cv2.inRange(image, lower, upper)

cnts = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]

colonies = []

for c in cnts:
    cv2.drawContours(image, [c], -1, (0, 255, 0), 2)
    colonies.append(c)

print(len(colonies))
cv2.imshow('mask', mask)
cv2.imshow('image', image)
cv2.imwrite('mask.png', mask)
cv2.imwrite('image.png', image)
cv2.waitKey()
# Out:
# 6242
# QObject::moveToThread: Current thread (0x55b9d0d233f0) is not the object's thread (0x55b9d12c9e60).
# Cannot move to target thread (0x55b9d0d233f0)
#
# QObject::moveToThread: Current thread (0x55b9d0d233f0) is not the object's thread (0x55b9d12c9e60).
# Cannot move to target thread (0x55b9d0d233f0)
#
# QObject::moveToThread: Current thread (0x55b9d0d233f0) is not the object's thread (0x55b9d12c9e60).
# Cannot move to target thread (0x55b9d0d233f0)
#
# QObject::moveToThread: Current thread (0x55b9d0d233f0) is not the object's thread (0x55b9d12c9e60).
# Cannot move to target thread (0x55b9d0d233f0)
#
# QObject::moveToThread: Current thread (0x55b9d0d233f0) is not the object's thread (0x55b9d12c9e60).
# Cannot move to target thread (0x55b9d0d233f0)
#
# QObject::moveToThread: Current thread (0x55b9d0d233f0) is not the object's thread (0x55b9d12c9e60).
# Cannot move to target thread (0x55b9d0d233f0)
#
# ...

# %%
# de momento, el mejor códugo para hacer lo que quiero*


import cv2

path_bs='./data/brush_strokes/'
image = cv2.imread(path_bs + "bs_05.jpg")
#gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
canny = cv2.Canny(image, 10, 150)
canny = cv2.dilate(canny, None, iterations=1)
canny = cv2.erode(canny, None, iterations=1)

#cv2.imshow('image',image)
#cv2.imshow('canny',canny)

#_, th = cv2.threshold(canny, 10, 255, cv2.THRESH_BINARY)
#_,cnts,_ = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)# OpenCV 3
#contours, hierarchy = cv2.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
contours,hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE) # OpenCV 4

#cv2.drawContours(image, contours, -1, (0,255,0), 3) #cv2.drawContours(image, contours, -1, (0,255,0), 2)  
#cv2.imshow('image',image)
#cv2.waitKey(0)


#cnt = contours[0]
#cv2.drawContours(image, [cnt], 0, (0,255,0), 3)
#cv2.imshow('image',image)
#cv2.waitKey(0)

#for idx in range(len(contours))
#save area inside each contour from the image
idx=50
cnt=contours[idx]
cv2.drawContours(image, [cnt], 0, (0,255,0), 2)
cv2.imshow('image',image)
cv2.waitKey(0)
# Out:
# QObject::moveToThread: Current thread (0x560e6c287da0) is not the object's thread (0x560e6c4287f0).
# Cannot move to target thread (0x560e6c287da0)
#
# QObject::moveToThread: Current thread (0x560e6c287da0) is not the object's thread (0x560e6c4287f0).
# Cannot move to target thread (0x560e6c287da0)
#
# QObject::moveToThread: Current thread (0x560e6c287da0) is not the object's thread (0x560e6c4287f0).
# Cannot move to target thread (0x560e6c287da0)
#
# QObject::moveToThread: Current thread (0x560e6c287da0) is not the object's thread (0x560e6c4287f0).
# Cannot move to target thread (0x560e6c287da0)
#
# QObject::moveToThread: Current thread (0x560e6c287da0) is not the object's thread (0x560e6c4287f0).
# Cannot move to target thread (0x560e6c287da0)
#
# QObject::moveToThread: Current thread (0x560e6c287da0) is not the object's thread (0x560e6c4287f0).
# Cannot move to target thread (0x560e6c287da0)
#
# ...

# %%
#for idx in range(len(contours))
#save area inside each contour from the image
idx=0
cnt=contours[idx]
cv2.drawContours(image, [cnt], 0, (0,255,0), 2)

# %%
import cv2
import numpy as np

path_bs='./data/brush_strokes/'
image = cv2.imread(path_bs + "bs_05.jpg")
#gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
canny = cv2.Canny(image, 10, 150)
canny = cv2.dilate(canny, None, iterations=1)
canny = cv2.erode(canny, None, iterations=1)

#cv2.imshow('image',image)
#cv2.imshow('canny',canny)

#_, th = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)
#_,cnts,_ = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)# OpenCV 3
#contours, hierarchy = cv2.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
contours,hierarchy = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE) # OpenCV 4

#cv2.drawContours(image, contours, -1, (0,255,0), 2) #cv2.drawContours(image, contours, -1, (0,255,0), 2)  
#cv2.imshow('image',image)
#cv2.waitKey(0)



box_image = image[y : y+h, x: x+w]
cv2.imwrite("image_name.jpg", box_image)

contours[0]

area = cv2.contourArea(np.around(np.array([[pt] for pt in [contours[0]]])).astype(np.int32))


#for idx in range(len(contours))
#save area inside each contour from the image

#cnt=contours[idx]
#cv2.drawContours(image, [cnt], 0, (0,255,0), 2)


#cv2.imshow('image',image)
#cv2.waitKey(0)
type(area)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_2695/1728618518.py in <module>
#      23 contours[0]
#      24
# ---> 25 area = cv2.contourArea(np.around(np.array([[pt] for pt in [contours[0]]])).astype(np.int32))
#      26
#      27
#
# error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/shapedescr.cpp:315: error: (-215:Assertion failed) npoints >= 0 && (depth == CV_32F || depth == CV_32S) in function 'contourArea'

# %%
import numpy as np
from PIL import Image

path_bs='./data/brush_strokes/'

im = np.array(Image.open(path_bs + "bs_05.jpg"))

print("Before trimming:",im.shape)

im_trim = im[128:384, 128:384]
print("After trimming:",im_trim.shape)

#Image.fromarray(im_trim).save( path + 'trim_AH01.jpg')
# Out:
# Before trimming: (800, 800)
# After trimming: (256, 256)

# %%
contours[0]

# %%
lstBoundingBoxes = []
for cnt in contours:  lstBoundingBoxes.append(cv2.boundingRect(cnt))
lstBoundingBoxes.sort()

charNo=0
for item in lstBoundingBoxes[1:]: # skip first element ('bounding box' == entire image)
    charNo += 1
    fName = "charAtPosNo-" + str(charNo).zfill(2) + "_is_[ " + strFormula[charNo-1] + " ]"+ ".png"; 
    x,y,w,h = item
    cv2.imwrite(fName, img[y:y+h, x:x+w])

# %%
import cv2


path_bs='./data/brush_strokes/'
img = cv2.imread(path_bs + "bs_05.jpg")


strFormula="1!((x+1)*(x+2))" # '!' means a character is not allowed in file name
#img = cv2.imread("test26.png")
imgGray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
ret, imgThresh = cv2.threshold(imgGray, 127, 255, 0)

(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')
if int(major_ver)  < 3 :
    contours , hierarchy  = cv2.findContours(imgThresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
else :
    image, contours , _   = cv2.findContours(imgThresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#:if

lstBoundingBoxes = []
for cnt in contours:  lstBoundingBoxes.append(cv2.boundingRect(cnt))
lstBoundingBoxes.sort()

charNo=0
for item in lstBoundingBoxes[1:]: # skip first element ('bounding box' == entire image)
    charNo += 1
    fName = "charAtPosNo-" + str(charNo).zfill(2) + "_is_[ " + strFormula[charNo-1] + " ]"+ ".png"; 
    x,y,w,h = item
    cv2.imwrite(fName, img[y:y+h, x:x+w])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3886/2368167577.py in <module>
#      15     contours , hierarchy  = cv2.findContours(imgThresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#      16 else :
# ---> 17     image, contours , _   = cv2.findContours(imgThresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#      18 #:if
#      19
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
import cv2


path_bs='./data/brush_strokes/'
img = cv2.imread(path_bs + "bs_05.jpg")


strFormula="1!((x+1)*(x+2))" # '!' means a character is not allowed in file name
#img = cv2.imread("test26.png")
imgGray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
ret, imgThresh = cv2.threshold(imgGray, 127, 255, 0)

(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')
if int(major_ver)  < 3 :
    contours , hierarchy  = cv2.findContours(imgThresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
else :
    image, contours , _   = cv2.findContours(imgThresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#:if

lstBoundingBoxes = []
for cnt in contours:  lstBoundingBoxes.append(cv2.boundingRect(cnt))
lstBoundingBoxes.sort()

type(lstBoundingBoxes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3886/2583325928.py in <module>
#      15     contours , hierarchy  = cv2.findContours(imgThresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#      16 else :
# ---> 17     image, contours , _   = cv2.findContours(imgThresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#      18 #:if
#      19
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#ko
import cv2

path_bs='./data/brush_strokes/'

def show_image(image):
    cv2.imshow('image',image)
    c = cv2.waitKey()
    if c >= 0 : return -1
    return 0

image = cv2.imread(path_bs + "bs_05.jpg")
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, im = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY_INV)
contours, hierarchy  = cv2.findContours(im, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
img = cv2.drawContours(image, contours, -1, (0,255,75), 2)
show_image(img)

# %%
for c in range(len(contours)):
    n_contour = contours[c]
    for d in range(len(n_contour)):
        XY_Coordinates = n_contour[d]
        print(XY_Coordinates)
